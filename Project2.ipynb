# %%
from uber_rides.session import Session
session = Session(server_token="TZ9aAN7GMzp49djfXoMil2HJ7XxCs0Zwo8EWXd88")

# %%
from uber_rides.client import UberRidesClient
client = UberRidesClient(session)
response = client.get_products(33.75, -84.39)
products = response.json.get('products')

# %%
##ATLANTA TO SMYRNA
response = client.get_price_estimates(
    start_latitude=33.7490,
    start_longitude=-84.3880,
    end_latitude=33.8840,
    end_longitude=-84.5114,
    seat_count=2
)

estimate = response.json.get('prices')

# %%
print(estimate)
# Out:
# [{'localized_display_name': 'UberPool', 'distance': 15.49, 'display_name': 'UberPool', 'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0', 'high_estimate': 24.0, 'low_estimate': 18.0, 'duration': 1620, 'estimate': '$18-23', 'currency_code': 'USD'}, {'localized_display_name': 'UberX', 'distance': 15.49, 'display_name': 'UberX', 'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a', 'high_estimate': 24.0, 'low_estimate': 18.0, 'duration': 1620, 'estimate': '$18-24', 'currency_code': 'USD'}, {'localized_display_name': 'UberXL', 'distance': 15.49, 'display_name': 'UberXL', 'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a', 'high_estimate': 50.0, 'low_estimate': 40.0, 'duration': 1620, 'estimate': '$40-50', 'currency_code': 'USD'}, {'localized_display_name': 'Select', 'distance': 15.49, 'display_name': 'Select', 'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1', 'high_estimate': 53.0, 'low_estimate': 43.0, 'duration': 1620, 'estimate': '$43-53', 'currency_code': 'USD'}, {'localized_display_name': 'Black', 'distance': 15.49, 'display_name': 'Black', 'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b', 'high_estimate': 77.0, 'low_estimate': 62.0, 'duration': 1620, 'estimate': '$62-77', 'currency_code': 'USD'}, {'localized_display_name': 'Black SUV', 'distance': 15.49, 'display_name': 'Black SUV', 'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6', 'high_estimate': 102.0, 'low_estimate': 82.0, 'duration': 1620, 'estimate': '$82-102', 'currency_code': 'USD'}]

# %%
##ATLANTA TO ALPHARETTA
response = client.get_price_estimates(
    start_latitude=33.7490,
    start_longitude=-84.3880,
    end_latitude=34.0754,
    end_longitude=-84.2941,
    seat_count=2
)

estimate2 = response.json.get('prices')
print(estimate2)
# Out:
# [{'localized_display_name': 'UberPool', 'distance': 27.01, 'display_name': 'UberPool', 'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0', 'high_estimate': 35.0, 'low_estimate': 27.0, 'duration': 2580, 'estimate': '$27-34', 'currency_code': 'USD'}, {'localized_display_name': 'UberX', 'distance': 27.01, 'display_name': 'UberX', 'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a', 'high_estimate': 36.0, 'low_estimate': 29.0, 'duration': 2580, 'estimate': '$29-36', 'currency_code': 'USD'}, {'localized_display_name': 'UberXL', 'distance': 27.01, 'display_name': 'UberXL', 'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a', 'high_estimate': 81.0, 'low_estimate': 65.0, 'duration': 2580, 'estimate': '$65-81', 'currency_code': 'USD'}, {'localized_display_name': 'Select', 'distance': 27.01, 'display_name': 'Select', 'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1', 'high_estimate': 86.0, 'low_estimate': 69.0, 'duration': 2580, 'estimate': '$69-86', 'currency_code': 'USD'}, {'localized_display_name': 'Black', 'distance': 27.01, 'display_name': 'Black', 'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b', 'high_estimate': 126.0, 'low_estimate': 103.0, 'duration': 2580, 'estimate': '$103-126', 'currency_code': 'USD'}, {'localized_display_name': 'Black SUV', 'distance': 27.01, 'display_name': 'Black SUV', 'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6', 'high_estimate': 163.0, 'low_estimate': 132.0, 'duration': 2580, 'estimate': '$132-163', 'currency_code': 'USD'}]

# %%
import json

response = app.requests_session.post(
url,
headers=generate_ride_headers(session.get('TZ9aAN7GMzp49djfXoMil2HJ7XxCs0Zwo8EWXd88')),
data=json.dumps(params))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-15f0758b3e52> in <module>()
#       1 import json
#       2
# ----> 3 response = app.requests_session.post(
#       4 url,
#       5 headers=generate_ride_headers(session.get('TZ9aAN7GMzp49djfXoMil2HJ7XxCs0Zwo8EWXd88')),
#
# NameError: name 'app' is not defined

# %%
#Global Learning Center GA TECH: 33.7762° N, 84.3895° W
#centennial park: 33.7603474,-84.3957012
#Buckhead bars: 33.8439849,-84.3789694
#Inman park: 33.7613676,-84.3623401
#Stone Mountain: 33.8053189,-84.1477255
#Six flags: 33.7706408,-84.5537186

# %%
##global learning center TO CENTENNIAL PARK
response = client.get_price_estimates(
    start_latitude=33.7762,
    start_longitude=-84.3895,
    end_latitude=33.7603474,
    end_longitude=-84.3789694,
    seat_count=2
)

estimate6 = response.json.get('prices')
print(estimate6)
estimate6
# Out:
# [{'localized_display_name': 'UberPool', 'distance': 2.11, 'display_name': 'UberPool', 'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0', 'high_estimate': 10.0, 'low_estimate': 7.0, 'duration': 540, 'estimate': '$7-9', 'currency_code': 'USD'}, {'localized_display_name': 'UberX', 'distance': 2.11, 'display_name': 'UberX', 'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a', 'high_estimate': 10.0, 'low_estimate': 7.0, 'duration': 540, 'estimate': '$7-10', 'currency_code': 'USD'}, {'localized_display_name': 'UberXL', 'distance': 2.11, 'display_name': 'UberXL', 'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a', 'high_estimate': 15.0, 'low_estimate': 11.0, 'duration': 540, 'estimate': '$11-15', 'currency_code': 'USD'}, {'localized_display_name': 'Select', 'distance': 2.11, 'display_name': 'Select', 'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1', 'high_estimate': 16.0, 'low_estimate': 12.0, 'duration': 540, 'estimate': '$12-16', 'currency_code': 'USD'}, {'localized_display_name': 'Black', 'distance': 2.11, 'display_name': 'Black', 'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b', 'high_estimate': 20.0, 'low_estimate': 16.0, 'duration': 540, 'estimate': '$16-20', 'currency_code': 'USD'}, {'localized_display_name': 'Black SUV', 'distance': 2.11, 'display_name': 'Black SUV', 'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6', 'high_estimate': 31.0, 'low_estimate': 24.0, 'duration': 540, 'estimate': '$24-31', 'currency_code': 'USD'}]
# [{'localized_display_name': 'UberPool',
#   'distance': 2.11,
#   'display_name': 'UberPool',
#   'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#   'high_estimate': 10.0,
#   'low_estimate': 7.0,
#   'duration': 540,
#   'estimate': '$7-9',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'UberX',
#   'distance': 2.11,
#   'display_name': 'UberX',
#   'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#   'high_estimate': 10.0,
#   'low_estimate': 7.0,
#   'duration': 540,
#   'estimate': '$7-10',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'UberXL',
#   'distance': 2.11,
#   'display_name': 'UberXL',
#   'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#   'high_estimate': 15.0,
#   'low_estimate': 11.0,
#   'duration': 540,
#   'estimate': '$11-15',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Select',
#   'distance': 2.11,
#   'display_name': 'Select',
#   'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#   'high_estimate': 16.0,
#   'low_estimate': 12.0,
#   'duration': 540,
#   'estimate': '$12-16',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Black',
#   'distance': 2.11,
#   'display_name': 'Black',
#   'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#   'high_estimate': 20.0,
#   'low_estimate': 16.0,
#   'duration': 540,
#   'estimate': '$16-20',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Black SUV',
#   'distance': 2.11,
#   'display_name': 'Black SUV',
#   'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#   'high_estimate': 31.0,
#   'low_estimate': 24.0,
#   'duration': 540,
#   'estimate': '$24-31',
#   'currency_code': 'USD'}]

# %%
#Buckhead bars: 33.8439849,-84.3789694
##global learning center TO buckhead Bars
response = client.get_price_estimates(
    start_latitude=33.7762,
    start_longitude=-84.3895,
    end_latitude=33.8439849,
    end_longitude=-84.3789694,
    seat_count=2
)

estimate7 = response.json.get('prices')
print(estimate7)
estimate7
# Out:
# [{'localized_display_name': 'UberPool', 'distance': 7.07, 'display_name': 'UberPool', 'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0', 'high_estimate': 15.0, 'low_estimate': 11.0, 'duration': 1380, 'estimate': '$11-14', 'currency_code': 'USD'}, {'localized_display_name': 'UberX', 'distance': 7.07, 'display_name': 'UberX', 'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a', 'high_estimate': 15.0, 'low_estimate': 12.0, 'duration': 1380, 'estimate': '$12-15', 'currency_code': 'USD'}, {'localized_display_name': 'UberXL', 'distance': 7.07, 'display_name': 'UberXL', 'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a', 'high_estimate': 30.0, 'low_estimate': 24.0, 'duration': 1380, 'estimate': '$24-30', 'currency_code': 'USD'}, {'localized_display_name': 'Select', 'distance': 7.07, 'display_name': 'Select', 'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1', 'high_estimate': 33.0, 'low_estimate': 26.0, 'duration': 1380, 'estimate': '$26-33', 'currency_code': 'USD'}, {'localized_display_name': 'Black', 'distance': 7.07, 'display_name': 'Black', 'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b', 'high_estimate': 45.0, 'low_estimate': 36.0, 'duration': 1380, 'estimate': '$36-45', 'currency_code': 'USD'}, {'localized_display_name': 'Black SUV', 'distance': 7.07, 'display_name': 'Black SUV', 'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6', 'high_estimate': 61.0, 'low_estimate': 49.0, 'duration': 1380, 'estimate': '$49-61', 'currency_code': 'USD'}]
# [{'localized_display_name': 'UberPool',
#   'distance': 7.07,
#   'display_name': 'UberPool',
#   'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#   'high_estimate': 15.0,
#   'low_estimate': 11.0,
#   'duration': 1380,
#   'estimate': '$11-14',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'UberX',
#   'distance': 7.07,
#   'display_name': 'UberX',
#   'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#   'high_estimate': 15.0,
#   'low_estimate': 12.0,
#   'duration': 1380,
#   'estimate': '$12-15',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'UberXL',
#   'distance': 7.07,
#   'display_name': 'UberXL',
#   'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#   'high_estimate': 30.0,
#   'low_estimate': 24.0,
#   'duration': 1380,
#   'estimate': '$24-30',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Select',
#   'distance': 7.07,
#   'display_name': 'Select',
#   'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#   'high_estimate': 33.0,
#   'low_estimate': 26.0,
#   'duration': 1380,
#   'estimate': '$26-33',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Black',
#   'distance': 7.07,
#   'display_name': 'Black',
#   'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#   'high_estimate': 45.0,
#   'low_estimate': 36.0,
#   'duration': 1380,
#   'estimate': '$36-45',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Black SUV',
#   'distance': 7.07,
#   'display_name': 'Black SUV',
#   'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#   'high_estimate': 61.0,
#   'low_estimate': 49.0,
#   'duration': 1380,
#   'estimate': '$49-61',
#   'currency_code': 'USD'}]

# %%
#Inman park: 33.7613676,-84.3623401
##global learning center TO Inman Park
response = client.get_price_estimates(
    start_latitude=33.7762,
    start_longitude=-84.3895,
    end_latitude=33.7613676,
    end_longitude=-84.3623401,
    seat_count=2
)

estimate8 = response.json.get('prices')
print(estimate8)
estimate8
# Out:
# [{'localized_display_name': 'UberPool', 'distance': 7.07, 'display_name': 'UberPool', 'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0', 'high_estimate': 15.0, 'low_estimate': 11.0, 'duration': 1380, 'estimate': '$11-14', 'currency_code': 'USD'}, {'localized_display_name': 'UberX', 'distance': 7.07, 'display_name': 'UberX', 'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a', 'high_estimate': 15.0, 'low_estimate': 12.0, 'duration': 1380, 'estimate': '$12-15', 'currency_code': 'USD'}, {'localized_display_name': 'UberXL', 'distance': 7.07, 'display_name': 'UberXL', 'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a', 'high_estimate': 30.0, 'low_estimate': 24.0, 'duration': 1380, 'estimate': '$24-30', 'currency_code': 'USD'}, {'localized_display_name': 'Select', 'distance': 7.07, 'display_name': 'Select', 'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1', 'high_estimate': 33.0, 'low_estimate': 26.0, 'duration': 1380, 'estimate': '$26-33', 'currency_code': 'USD'}, {'localized_display_name': 'Black', 'distance': 7.07, 'display_name': 'Black', 'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b', 'high_estimate': 45.0, 'low_estimate': 36.0, 'duration': 1380, 'estimate': '$36-45', 'currency_code': 'USD'}, {'localized_display_name': 'Black SUV', 'distance': 7.07, 'display_name': 'Black SUV', 'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6', 'high_estimate': 61.0, 'low_estimate': 49.0, 'duration': 1380, 'estimate': '$49-61', 'currency_code': 'USD'}]
# [{'localized_display_name': 'UberPool',
#   'distance': 2.55,
#   'display_name': 'UberPool',
#   'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#   'high_estimate': 9.0,
#   'low_estimate': 6.0,
#   'duration': 720,
#   'estimate': '$6-8',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'UberX',
#   'distance': 2.55,
#   'display_name': 'UberX',
#   'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#   'high_estimate': 9.0,
#   'low_estimate': 6.0,
#   'duration': 720,
#   'estimate': '$6-9',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'UberXL',
#   'distance': 2.55,
#   'display_name': 'UberXL',
#   'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#   'high_estimate': 17.0,
#   'low_estimate': 13.0,
#   'duration': 720,
#   'estimate': '$13-17',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Select',
#   'distance': 2.55,
#   'display_name': 'Select',
#   'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#   'high_estimate': 18.0,
#   'low_estimate': 14.0,
#   'duration': 720,
#   'estimate': '$14-18',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Black',
#   'distance': 2.55,
#   'display_name': 'Black',
#   'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#   'high_estimate': 23.0,
#   'low_estimate': 18.0,
#   'duration': 720,
#   'estimate': '$18-23',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Black SUV',
#   'distance': 2.55,
#   'display_name': 'Black SUV',
#   'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#   'high_estimate': 34.0,
#   'low_estimate': 27.0,
#   'duration': 720,
#   'estimate': '$27-34',
#   'currency_code': 'USD'}]

# %%
#Stone Mountain: 33.8053189,-84.1477255
##global learning center TO tone Mountain
response = client.get_price_estimates(
    start_latitude=33.7762,
    start_longitude=-84.3895,
    end_latitude=33.8053189,
    end_longitude=-84.1477255,
    seat_count=2
)

estimate9 = response.json.get('prices')
print(estimate9)
estimate9
# Out:
# [{'localized_display_name': 'UberPool', 'distance': 7.07, 'display_name': 'UberPool', 'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0', 'high_estimate': 15.0, 'low_estimate': 11.0, 'duration': 1380, 'estimate': '$11-14', 'currency_code': 'USD'}, {'localized_display_name': 'UberX', 'distance': 7.07, 'display_name': 'UberX', 'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a', 'high_estimate': 15.0, 'low_estimate': 12.0, 'duration': 1380, 'estimate': '$12-15', 'currency_code': 'USD'}, {'localized_display_name': 'UberXL', 'distance': 7.07, 'display_name': 'UberXL', 'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a', 'high_estimate': 30.0, 'low_estimate': 24.0, 'duration': 1380, 'estimate': '$24-30', 'currency_code': 'USD'}, {'localized_display_name': 'Select', 'distance': 7.07, 'display_name': 'Select', 'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1', 'high_estimate': 33.0, 'low_estimate': 26.0, 'duration': 1380, 'estimate': '$26-33', 'currency_code': 'USD'}, {'localized_display_name': 'Black', 'distance': 7.07, 'display_name': 'Black', 'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b', 'high_estimate': 45.0, 'low_estimate': 36.0, 'duration': 1380, 'estimate': '$36-45', 'currency_code': 'USD'}, {'localized_display_name': 'Black SUV', 'distance': 7.07, 'display_name': 'Black SUV', 'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6', 'high_estimate': 61.0, 'low_estimate': 49.0, 'duration': 1380, 'estimate': '$49-61', 'currency_code': 'USD'}]
# [{'localized_display_name': 'UberPool',
#   'distance': 23.99,
#   'display_name': 'UberPool',
#   'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#   'high_estimate': 35.0,
#   'low_estimate': 27.0,
#   'duration': 2940,
#   'estimate': '$27-34',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'UberX',
#   'distance': 23.99,
#   'display_name': 'UberX',
#   'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#   'high_estimate': 36.0,
#   'low_estimate': 28.0,
#   'duration': 2940,
#   'estimate': '$28-36',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'UberXL',
#   'distance': 23.99,
#   'display_name': 'UberXL',
#   'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#   'high_estimate': 77.0,
#   'low_estimate': 62.0,
#   'duration': 2940,
#   'estimate': '$62-77',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Select',
#   'distance': 23.99,
#   'display_name': 'Select',
#   'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#   'high_estimate': 81.0,
#   'low_estimate': 66.0,
#   'duration': 2940,
#   'estimate': '$66-81',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Black',
#   'distance': 23.99,
#   'display_name': 'Black',
#   'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#   'high_estimate': 118.0,
#   'low_estimate': 96.0,
#   'duration': 2940,
#   'estimate': '$96-118',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Black SUV',
#   'distance': 23.99,
#   'display_name': 'Black SUV',
#   'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#   'high_estimate': 153.0,
#   'low_estimate': 124.0,
#   'duration': 2940,
#   'estimate': '$124-153',
#   'currency_code': 'USD'}]

# %%
#Six flags: 33.7706408,-84.5537186
##global learning center TO Six Flags
response = client.get_price_estimates(
    start_latitude=33.7762,
    start_longitude=-84.3895,
    end_latitude=33.8053189,
    end_longitude=-84.1477255,
    seat_count=2
)

estimate10 = response.json.get('prices')
print(estimate10)
estimate10
# Out:
# [{'localized_display_name': 'UberPool', 'distance': 18.76, 'display_name': 'UberPool', 'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0', 'high_estimate': 30.0, 'low_estimate': 23.0, 'duration': 2940, 'estimate': '$23-29', 'currency_code': 'USD'}, {'localized_display_name': 'UberX', 'distance': 18.76, 'display_name': 'UberX', 'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a', 'high_estimate': 31.0, 'low_estimate': 24.0, 'duration': 2940, 'estimate': '$24-31', 'currency_code': 'USD'}, {'localized_display_name': 'UberXL', 'distance': 18.76, 'display_name': 'UberXL', 'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a', 'high_estimate': 65.0, 'low_estimate': 52.0, 'duration': 2940, 'estimate': '$52-65', 'currency_code': 'USD'}, {'localized_display_name': 'Select', 'distance': 18.76, 'display_name': 'Select', 'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1', 'high_estimate': 69.0, 'low_estimate': 56.0, 'duration': 2940, 'estimate': '$56-69', 'currency_code': 'USD'}, {'localized_display_name': 'Black', 'distance': 18.76, 'display_name': 'Black', 'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b', 'high_estimate': 99.0, 'low_estimate': 80.0, 'duration': 2940, 'estimate': '$80-99', 'currency_code': 'USD'}, {'localized_display_name': 'Black SUV', 'distance': 18.76, 'display_name': 'Black SUV', 'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6', 'high_estimate': 129.0, 'low_estimate': 105.0, 'duration': 2940, 'estimate': '$105-129', 'currency_code': 'USD'}]
# [{'localized_display_name': 'UberPool',
#   'distance': 18.76,
#   'display_name': 'UberPool',
#   'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#   'high_estimate': 30.0,
#   'low_estimate': 23.0,
#   'duration': 2940,
#   'estimate': '$23-29',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'UberX',
#   'distance': 18.76,
#   'display_name': 'UberX',
#   'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#   'high_estimate': 31.0,
#   'low_estimate': 24.0,
#   'duration': 2940,
#   'estimate': '$24-31',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'UberXL',
#   'distance': 18.76,
#   'display_name': 'UberXL',
#   'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#   'high_estimate': 65.0,
#   'low_estimate': 52.0,
#   'duration': 2940,
#   'estimate': '$52-65',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Select',
#   'distance': 18.76,
#   'display_name': 'Select',
#   'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#   'high_estimate': 69.0,
#   'low_estimate': 56.0,
#   'duration': 2940,
#   'estimate': '$56-69',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Black',
#   'distance': 18.76,
#   'display_name': 'Black',
#   'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#   'high_estimate': 99.0,
#   'low_estimate': 80.0,
#   'duration': 2940,
#   'estimate': '$80-99',
#   'currency_code': 'USD'},
#  {'localized_display_name': 'Black SUV',
#   'distance': 18.76,
#   'display_name': 'Black SUV',
#   'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#   'high_estimate': 129.0,
#   'low_estimate': 105.0,
#   'duration': 2940,
#   'estimate': '$105-129',
#   'currency_code': 'USD'}]

# %%
places = [
    { "name": "Centenniel Park",
    "location": [33.7603474,-84.3957012]},
    { "name": "Buckhead Bars",
    "location": [33.8439849,-84.3789694]},
    { "name": "Inman Park",
    "location": [33.7613676,-84.3623401]},
    { "name": "Stone Mountain",
    "location": [33.8053189,-84.1477255]},
    { "name": "Six Flags",
    "location": [33.7706408,-84.5537186]}]
total_estimates = []
estimates = {}
for place in places:
    estimates = {}
    print(place["name"])
    estimates["place"] = place["name"]
    #estimates["value"] = estimate
    total_estimates.append(estimates)
total_estimates
# Out:
# Centenniel Park
# Buckhead Bars
# Inman Park
# Stone Mountain
# Six Flags
# [{'place': 'Six Flags'},
#  {'place': 'Six Flags'},
#  {'place': 'Six Flags'},
#  {'place': 'Six Flags'},
#  {'place': 'Six Flags'}]

# %%
places = [
  { "name": "Centennial Park",
  "location": [33.7603474,-84.3957012]},
  { "name": "Buckhead Bars",
  "location": [33.8439849,-84.3789694]},
  { "name": "Inman Park",
  "location": [33.7613676,-84.3623401]},
  { "name": "Stone Mountain",
  "location": [33.8053189,-84.1477255]},
  { "name": "Six Flags",
  "location": [33.7706408,-84.5537186]},
  { "name": "Statefarm Arena",
 "location": [33.7572891,-84.3963244]},
 { "name": "Zoo Atlanta",
 "location": [33.7327032,-84.3846396]},
 { "name": "Atlanta High Museum",
 "location": [33.7900632,-84.3877407]},
 { "name": "Fox Theater",
 "location": [33.7724591,-84.3879697]},
 { "name": "Virginia Highlands",
 "location": [33.7795027,-84.3757217]},
 { "name": "Shops at Buckhead",
 "location": [33.838031,-84.3821468]},
 { "name": "Emory University",
 "location": [33.7925239,-84.3261929]},
 { "name": "Georgia State University",
 "location": [33.7530724,-84.3874759]},
 { "name": "Spelman College",
 "location": [33.7463641,-84.4144874]},
 { "name": "Edgewood Bars",
 "location": [33.7544814,-84.3745674]},
  {"name": "Hartsfield Jackson Airport",
  "location": [33.6407282,-84.4277001]},
   {"name":"SunTrust Park",
   "location":[33.8908211,-84.4678309]},
   {"name":"Mercedes Benz Stadium",
   "location":[33.7554483,-84.400855]},
   {"name":"Lenox Square Mall",
    "location":[33.8462925,-84.3621419]},
   {"name":"Piedmont Park",
   "location":[33.7850856,-84.373803]}]
total_estimates = []
estimates = {}
#Global Learning Center GA TECH: 33.7762° N, 84.3895° W
#centennial park: 33.7603474,-84.3957012
#Buckhead bars: 33.8439849,-84.3789694
#Inman park: 33.7613676,-84.3623401
#Stone Mountain: 33.8053189,-84.1477255
#Six flags: 33.7706408,-84.5537186
for place in places:
    estimates = {}
    response = client.get_price_estimates(
        start_latitude=33.7762,
        start_longitude=-84.3895,
        end_latitude=place["location"][0],
        end_longitude=place["location"][1]
    )

    estimate = response.json.get('prices')
    #print(estimate)
    #estimate10
    estimates["place"] = place["name"]
    estimates["geometry"] = place["location"]
    estimates["value"] = estimate
    total_estimates.append(estimates)
total_estimates
# Out:
# [{'place': 'Centennial Park',
#   'geometry': [33.7603474, -84.3957012],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.37,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 420,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.37,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 420,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.37,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 12.0,
#     'low_estimate': 9.0,
#     'duration': 420,
#     'estimate': '$9-12',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.37,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 14.0,
#     'low_estimate': 10.0,
#     'duration': 420,
#     'estimate': '$10-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.37,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 420,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.37,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 420,
#     'estimate': '$22-28',
#     'currency_code': 'USD'}]},
#  {'place': 'Buckhead Bars',
#   'geometry': [33.8439849, -84.3789694],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 7.49,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 13.0,
#     'low_estimate': 9.0,
#     'duration': 1080,
#     'estimate': '$9-12',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 7.49,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 15.0,
#     'low_estimate': 11.0,
#     'duration': 1080,
#     'estimate': '$11-15',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 7.49,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 30.0,
#     'low_estimate': 23.0,
#     'duration': 1080,
#     'estimate': '$23-30',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 7.49,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 32.0,
#     'low_estimate': 25.0,
#     'duration': 1080,
#     'estimate': '$25-32',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 7.49,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 44.0,
#     'low_estimate': 35.0,
#     'duration': 1080,
#     'estimate': '$35-44',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 7.49,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 60.0,
#     'low_estimate': 48.0,
#     'duration': 1080,
#     'estimate': '$48-60',
#     'currency_code': 'USD'}]},
#  {'place': 'Inman Park',
#   'geometry': [33.7613676, -84.3623401],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 2.56,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 660,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 2.56,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 660,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 2.56,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 16.0,
#     'low_estimate': 12.0,
#     'duration': 660,
#     'estimate': '$12-16',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 2.56,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 18.0,
#     'low_estimate': 14.0,
#     'duration': 660,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 2.56,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 23.0,
#     'low_estimate': 18.0,
#     'duration': 660,
#     'estimate': '$18-23',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 2.56,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 34.0,
#     'low_estimate': 27.0,
#     'duration': 660,
#     'estimate': '$27-34',
#     'currency_code': 'USD'}]},
#  {'place': 'Stone Mountain',
#   'geometry': [33.8053189, -84.1477255],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 18.66,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 28.0,
#     'low_estimate': 21.0,
#     'duration': 2100,
#     'estimate': '$21-27',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 18.66,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 2100,
#     'estimate': '$22-28',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 18.66,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 60.0,
#     'low_estimate': 48.0,
#     'duration': 2100,
#     'estimate': '$48-60',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 18.66,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 64.0,
#     'low_estimate': 51.0,
#     'duration': 2100,
#     'estimate': '$51-64',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 18.66,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 93.0,
#     'low_estimate': 75.0,
#     'duration': 2100,
#     'estimate': '$75-93',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 18.66,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 121.0,
#     'low_estimate': 98.0,
#     'duration': 2100,
#     'estimate': '$98-121',
#     'currency_code': 'USD'}]},
#  {'place': 'Six Flags',
#   'geometry': [33.7706408, -84.5537186],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 14.42,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 19.0,
#     'low_estimate': 14.0,
#     'duration': 1500,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 14.42,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 20.0,
#     'low_estimate': 16.0,
#     'duration': 1500,
#     'estimate': '$16-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 14.42,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 47.0,
#     'low_estimate': 38.0,
#     'duration': 1500,
#     'estimate': '$38-47',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 14.42,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 50.0,
#     'low_estimate': 40.0,
#     'duration': 1500,
#     'estimate': '$40-50',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 14.42,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 72.0,
#     'low_estimate': 58.0,
#     'duration': 1500,
#     'estimate': '$58-72',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 14.42,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 95.0,
#     'low_estimate': 77.0,
#     'duration': 1500,
#     'estimate': '$77-95',
#     'currency_code': 'USD'}]},
#  {'place': 'Statefarm Arena',
#   'geometry': [33.7572891, -84.3963244],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 2.09,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 540,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 2.09,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 10.0,
#     'low_estimate': 7.0,
#     'duration': 540,
#     'estimate': '$7-10',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 2.09,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 15.0,
#     'low_estimate': 11.0,
#     'duration': 540,
#     'estimate': '$11-15',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 2.09,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 16.0,
#     'low_estimate': 12.0,
#     'duration': 540,
#     'estimate': '$12-16',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 2.09,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 20.0,
#     'low_estimate': 15.0,
#     'duration': 540,
#     'estimate': '$15-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 2.09,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 31.0,
#     'low_estimate': 24.0,
#     'duration': 540,
#     'estimate': '$24-31',
#     'currency_code': 'USD'}]},
#  {'place': 'Zoo Atlanta',
#   'geometry': [33.7327032, -84.3846396],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 3.87,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 11.0,
#     'low_estimate': 7.0,
#     'duration': 780,
#     'estimate': '$7-10',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 3.87,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 11.0,
#     'low_estimate': 8.0,
#     'duration': 780,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 3.87,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 20.0,
#     'low_estimate': 15.0,
#     'duration': 780,
#     'estimate': '$15-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 3.87,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 22.0,
#     'low_estimate': 17.0,
#     'duration': 780,
#     'estimate': '$17-22',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 3.87,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 780,
#     'estimate': '$22-28',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 3.87,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 41.0,
#     'low_estimate': 32.0,
#     'duration': 780,
#     'estimate': '$32-41',
#     'currency_code': 'USD'}]},
#  {'place': 'Atlanta High Museum',
#   'geometry': [33.7900632, -84.3877407],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.32,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 5.0,
#     'duration': 420,
#     'estimate': '$5-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.32,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 420,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.32,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 12.0,
#     'low_estimate': 9.0,
#     'duration': 420,
#     'estimate': '$9-12',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.32,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 14.0,
#     'low_estimate': 10.0,
#     'duration': 420,
#     'estimate': '$10-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.32,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 420,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.32,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 420,
#     'estimate': '$22-28',
#     'currency_code': 'USD'}]},
#  {'place': 'Fox Theater',
#   'geometry': [33.7724591, -84.3879697],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 0.31,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 240,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 0.31,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 240,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 0.31,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 11.0,
#     'low_estimate': 8.0,
#     'duration': 240,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 0.31,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 13.0,
#     'low_estimate': 10.0,
#     'duration': 240,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 0.31,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 240,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 0.31,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 240,
#     'estimate': '$22-28',
#     'currency_code': 'USD'}]},
#  {'place': 'Virginia Highlands',
#   'geometry': [33.7795027, -84.3757217],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.02,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 8.0,
#     'low_estimate': 5.0,
#     'duration': 360,
#     'estimate': '$5-7',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.02,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 360,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.02,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 11.0,
#     'low_estimate': 8.0,
#     'duration': 360,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.02,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 13.0,
#     'low_estimate': 10.0,
#     'duration': 360,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.02,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 360,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.02,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 360,
#     'estimate': '$22-28',
#     'currency_code': 'USD'}]},
#  {'place': 'Shops at Buckhead',
#   'geometry': [33.838031, -84.3821468],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 7.12,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 11.0,
#     'low_estimate': 8.0,
#     'duration': 1080,
#     'estimate': '$8-10',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 7.12,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 14.0,
#     'low_estimate': 11.0,
#     'duration': 1080,
#     'estimate': '$11-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 7.12,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 29.0,
#     'low_estimate': 23.0,
#     'duration': 1080,
#     'estimate': '$23-29',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 7.12,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 31.0,
#     'low_estimate': 24.0,
#     'duration': 1080,
#     'estimate': '$24-31',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 7.12,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 42.0,
#     'low_estimate': 34.0,
#     'duration': 1080,
#     'estimate': '$34-42',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 7.12,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 58.0,
#     'low_estimate': 47.0,
#     'duration': 1080,
#     'estimate': '$47-58',
#     'currency_code': 'USD'}]},
#  {'place': 'Emory University',
#   'geometry': [33.7925239, -84.3261929],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 4.81,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 12.0,
#     'low_estimate': 8.0,
#     'duration': 1020,
#     'estimate': '$8-11',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 4.81,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 12.0,
#     'low_estimate': 9.0,
#     'duration': 1020,
#     'estimate': '$9-12',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 4.81,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 23.0,
#     'low_estimate': 18.0,
#     'duration': 1020,
#     'estimate': '$18-23',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 4.81,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 26.0,
#     'low_estimate': 20.0,
#     'duration': 1020,
#     'estimate': '$20-26',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 4.81,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 34.0,
#     'low_estimate': 27.0,
#     'duration': 1020,
#     'estimate': '$27-34',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 4.81,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 48.0,
#     'low_estimate': 38.0,
#     'duration': 1020,
#     'estimate': '$38-48',
#     'currency_code': 'USD'}]},
#  {'place': 'Georgia State University',
#   'geometry': [33.7530724, -84.3874759],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.85,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 540,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.85,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 540,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.85,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 14.0,
#     'low_estimate': 10.0,
#     'duration': 540,
#     'estimate': '$10-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.85,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 16.0,
#     'low_estimate': 12.0,
#     'duration': 540,
#     'estimate': '$12-16',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.85,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 19.0,
#     'low_estimate': 15.0,
#     'duration': 540,
#     'estimate': '$15-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.85,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 29.0,
#     'low_estimate': 23.0,
#     'duration': 540,
#     'estimate': '$23-29',
#     'currency_code': 'USD'}]},
#  {'place': 'Spelman College',
#   'geometry': [33.7463641, -84.4144874],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 3.52,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 720,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 3.52,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 720,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 3.52,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 19.0,
#     'low_estimate': 14.0,
#     'duration': 720,
#     'estimate': '$14-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 3.52,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 21.0,
#     'low_estimate': 16.0,
#     'duration': 720,
#     'estimate': '$16-21',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 3.52,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 27.0,
#     'low_estimate': 21.0,
#     'duration': 720,
#     'estimate': '$21-27',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 3.52,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 39.0,
#     'low_estimate': 31.0,
#     'duration': 720,
#     'estimate': '$31-39',
#     'currency_code': 'USD'}]},
#  {'place': 'Edgewood Bars',
#   'geometry': [33.7544814, -84.3745674],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 2.39,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 540,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 2.39,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 540,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 2.39,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 15.0,
#     'low_estimate': 12.0,
#     'duration': 540,
#     'estimate': '$12-15',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 2.39,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 17.0,
#     'low_estimate': 13.0,
#     'duration': 540,
#     'estimate': '$13-17',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 2.39,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 21.0,
#     'low_estimate': 16.0,
#     'duration': 540,
#     'estimate': '$16-21',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 2.39,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 32.0,
#     'low_estimate': 25.0,
#     'duration': 540,
#     'estimate': '$25-32',
#     'currency_code': 'USD'}]},
#  {'place': 'Hartsfield Jackson Airport',
#   'geometry': [33.6407282, -84.4277001],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 12.18,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 19.0,
#     'low_estimate': 14.0,
#     'duration': 1380,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 12.18,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 20.0,
#     'low_estimate': 15.0,
#     'duration': 1380,
#     'estimate': '$15-20',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 12.18,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 42.0,
#     'low_estimate': 33.0,
#     'duration': 1380,
#     'estimate': '$33-42',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 12.18,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 44.0,
#     'low_estimate': 35.0,
#     'duration': 1380,
#     'estimate': '$35-44',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 12.18,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 63.0,
#     'low_estimate': 51.0,
#     'duration': 1380,
#     'estimate': '$51-63',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 12.18,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 84.0,
#     'low_estimate': 68.0,
#     'duration': 1380,
#     'estimate': '$68-84',
#     'currency_code': 'USD'}]},
#  {'place': 'SunTrust Park',
#   'geometry': [33.8908211, -84.4678309],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 11.92,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 19.0,
#     'low_estimate': 14.0,
#     'duration': 1020,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 11.92,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 19.0,
#     'low_estimate': 14.0,
#     'duration': 1020,
#     'estimate': '$14-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 11.92,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 39.0,
#     'low_estimate': 31.0,
#     'duration': 1020,
#     'estimate': '$31-39',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 11.92,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 42.0,
#     'low_estimate': 33.0,
#     'duration': 1020,
#     'estimate': '$33-42',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 11.92,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 60.0,
#     'low_estimate': 48.0,
#     'duration': 1020,
#     'estimate': '$48-60',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 11.92,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 80.0,
#     'low_estimate': 65.0,
#     'duration': 1020,
#     'estimate': '$65-80',
#     'currency_code': 'USD'}]},
#  {'place': 'Mercedes Benz Stadium',
#   'geometry': [33.7554483, -84.400855],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.83,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 9.0,
#     'low_estimate': 6.0,
#     'duration': 600,
#     'estimate': '$6-8',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.83,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 10.0,
#     'low_estimate': 7.0,
#     'duration': 600,
#     'estimate': '$7-10',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.83,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 14.0,
#     'low_estimate': 11.0,
#     'duration': 600,
#     'estimate': '$11-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.83,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 16.0,
#     'low_estimate': 12.0,
#     'duration': 600,
#     'estimate': '$12-16',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.83,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 19.0,
#     'low_estimate': 15.0,
#     'duration': 600,
#     'estimate': '$15-19',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.83,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 30.0,
#     'low_estimate': 23.0,
#     'duration': 600,
#     'estimate': '$23-30',
#     'currency_code': 'USD'}]},
#  {'place': 'Lenox Square Mall',
#   'geometry': [33.8462925, -84.3621419],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 6.34,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 14.0,
#     'low_estimate': 9.0,
#     'duration': 1320,
#     'estimate': '$9-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 6.34,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 13.0,
#     'low_estimate': 10.0,
#     'duration': 1320,
#     'estimate': '$10-13',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 6.34,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 1320,
#     'estimate': '$22-28',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 6.34,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 31.0,
#     'low_estimate': 24.0,
#     'duration': 1320,
#     'estimate': '$24-31',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 6.34,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 41.0,
#     'low_estimate': 33.0,
#     'duration': 1320,
#     'estimate': '$33-41',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 6.34,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 57.0,
#     'low_estimate': 46.0,
#     'duration': 1320,
#     'estimate': '$46-57',
#     'currency_code': 'USD'}]},
#  {'place': 'Piedmont Park',
#   'geometry': [33.7850856, -84.373803],
#   'value': [{'localized_display_name': 'UberPool',
#     'distance': 1.54,
#     'display_name': 'UberPool',
#     'product_id': 'a9bd012e-768b-479d-8f04-9cecbb955fb0',
#     'high_estimate': 10.0,
#     'low_estimate': 6.0,
#     'duration': 600,
#     'estimate': '$6-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberX',
#     'distance': 1.54,
#     'display_name': 'UberX',
#     'product_id': '6d898741-0175-4c71-ad5f-93fc66270d6a',
#     'high_estimate': 9.0,
#     'low_estimate': 7.0,
#     'duration': 600,
#     'estimate': '$7-9',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'UberXL',
#     'distance': 1.54,
#     'display_name': 'UberXL',
#     'product_id': '171a12a5-5b08-40cc-bfb0-416b9256147a',
#     'high_estimate': 14.0,
#     'low_estimate': 10.0,
#     'duration': 600,
#     'estimate': '$10-14',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Select',
#     'distance': 1.54,
#     'display_name': 'Select',
#     'product_id': '3d3dff24-c799-45ba-ad08-3d72c5b843b1',
#     'high_estimate': 15.0,
#     'low_estimate': 12.0,
#     'duration': 600,
#     'estimate': '$12-15',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black',
#     'distance': 1.54,
#     'display_name': 'Black',
#     'product_id': 'aff35634-a71e-470f-8c7b-703dec02e15b',
#     'high_estimate': 18.0,
#     'low_estimate': 14.0,
#     'duration': 600,
#     'estimate': '$14-18',
#     'currency_code': 'USD'},
#    {'localized_display_name': 'Black SUV',
#     'distance': 1.54,
#     'display_name': 'Black SUV',
#     'product_id': '852310f8-a778-4191-bb7b-8c5f9a9899f6',
#     'high_estimate': 28.0,
#     'low_estimate': 22.0,
#     'duration': 600,
#     'estimate': '$22-28',
#     'currency_code': 'USD'}]}]

# %%
import json
with open('outfile.json', 'w') as outfile:
    json.dump(total_estimates, outfile)
